# %%
#加載單張圖片
from keras.preprocessing.image import img_to_array,load_img
from pathlib import Path

# %%
cur_path = Path.cwd()
print(cur_path)
pic='husky5.jpg'
pic1 = load_img(pic,target_size=(224,224))
print(pic1)
# Out:
# D:\AI\project\husky
# <PIL.Image.Image image mode=RGB size=224x224 at 0x234A6D940C8>

# %%
# 可視化第一張圖
from matplotlib import pyplot as plt
fig1  = plt.figure()
plt.imshow(pic1)

# %%
#圖片轉數組
pic1 = img_to_array(pic1)

# %%
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import VGG16
import numpy as np

x = np.expand_dims(pic1,axis=0)
x = preprocess_input(x)
model_vgg = VGG16(weights='imagenet', include_top=False)
features = model_vgg.predict(x)
features = features.reshape(1,7*7*512)
# Out:
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %%
import numpy as np

model_vgg = VGG16(weights='imagenet', include_top=False)
#define a method to load and preprocess the image
def modelProcess(img_path,model):
    img = load_img(img_path, target_size=(224, 224))
    img = img_to_array(img)
    x = np.expand_dims(img,axis=0)
    x = preprocess_input(x)
    x_vgg = model.predict(x)
    x_vgg = x_vgg.reshape(1,25088)
    return x_vgg
#list file names of the training datasets
import os
folder1 = "photos/husky/"
dirs1 = os.listdir(folder1)
#generate path for the images
img_path1 = []
for i in dirs1:
    if os.path.splitext(i)[1] == ".jpg":
        img_path1.append(i)
img_path1 = [folder1+"//"+i for i in img_path1]

#preprocess multiple images
features1 = np.zeros([len(img_path1),25088])
for i in range(len(img_path1)):
    feature_i = modelProcess(img_path1[i],model_vgg)
    print('preprocessed:',img_path1[i])
    features1[i] = feature_i

folder2 = "photos/wolf/"
dirs2 = os.listdir(folder2)
img_path2 = []
for i in dirs2:
    if os.path.splitext(i)[1] == ".jpg":
        img_path2.append(i)
img_path2 = [folder2+"//"+i for i in img_path2]
features2 = np.zeros([len(img_path2),25088])
for i in range(len(img_path2)):
    feature_i = modelProcess(img_path2[i],model_vgg)
    print('preprocessed:',img_path2[i])
    features2[i] = feature_i

#label the results
print(features1.shape,features2.shape)
y1 = np.zeros(195)
y2 = np.ones(359)

#generate the training data
X = np.concatenate((features1,features2),axis=0)
y = np.concatenate((y1,y2),axis=0)
y = y.reshape(-1,1)
print(X.shape,y.shape)
# Out:
# preprocessed: photos/husky///husky38.jpg
# preprocessed: photos/husky///husky380.jpg
# preprocessed: photos/husky///husky381.jpg
# preprocessed: photos/husky///husky382.jpg
# preprocessed: photos/husky///husky383.jpg
# preprocessed: photos/husky///husky384.jpg
# preprocessed: photos/husky///husky385.jpg
# preprocessed: photos/husky///husky386.jpg
# preprocessed: photos/husky///husky387.jpg
# preprocessed: photos/husky///husky388.jpg
# preprocessed: photos/husky///husky389.jpg
# preprocessed: photos/husky///husky39.jpg
# preprocessed: photos/husky///husky390.jpg
# preprocessed: photos/husky///husky391.jpg
# preprocessed: photos/husky///husky392.jpg
# preprocessed: photos/husky///husky393.jpg
# preprocessed: photos/husky///husky394.jpg
# preprocessed: photos/husky///husky395.jpg
# preprocessed: photos/husky///husky396.jpg
# preprocessed: photos/husky///husky397.jpg
# preprocessed: photos/husky///husky399.jpg
# preprocessed: photos/husky///husky40.jpg
# preprocessed: photos/husky///husky400.jpg
# preprocessed: photos/husky///husky401.jpg
# preprocessed: photos/husky///husky402.jpg
# preprocessed: photos/husky///husky403.jpg
# preprocessed: photos/husky///husky404.jpg
# preprocessed: photos/husky///husky406.jpg
# preprocessed: photos/husky///husky407.jpg
# preprocessed: photos/husky///husky409.jpg
# preprocessed: photos/husky///husky41.jpg
# preprocessed: photos/husky///husky410.jpg
# preprocessed: photos/husky///husky411.jpg
# preprocessed: photos/husky///husky412.jpg
# preprocessed: photos/husky///husky413.jpg
# preprocessed: photos/husky///husky414.jpg
# preprocessed: photos/husky///husky415.jpg
# preprocessed: photos/husky///husky417.jpg
# preprocessed: photos/husky///husky418.jpg
# preprocessed: photos/husky///husky419.jpg
# preprocessed: photos/husky///husky42.jpg
# preprocessed: photos/husky///husky420.jpg
# preprocessed: photos/husky///husky421.jpg
# preprocessed: photos/husky///husky422.jpg
# preprocessed: photos/husky///husky423.jpg
# preprocessed: photos/husky///husky424.jpg
# preprocessed: photos/husky///husky425.jpg
# preprocessed: photos/husky///husky426.jpg
# preprocessed: photos/husky///husky427.jpg
# preprocessed: photos/husky///husky428.jpg
# preprocessed: photos/husky///husky43.jpg
# preprocessed: photos/husky///husky430.jpg
# preprocessed: photos/husky///husky431.jpg
# preprocessed: photos/husky///husky432.jpg
# preprocessed: photos/husky///husky433.jpg
# preprocessed: photos/husky///husky435.jpg
# preprocessed: photos/husky///husky436.jpg
# preprocessed: photos/husky///husky437.jpg
# preprocessed: photos/husky///husky438.jpg
# preprocessed: photos/husky///husky439.jpg
# preprocessed: photos/husky///husky44.jpg
# preprocessed: photos/husky///husky440.jpg
# preprocessed: photos/husky///husky441.jpg
# preprocessed: photos/husky///husky442.jpg
# preprocessed: photos/husky///husky443.jpg
# preprocessed: photos/husky///husky445.jpg
# preprocessed: photos/husky///husky446.jpg
# preprocessed: photos/husky///husky447.jpg
# preprocessed: photos/husky///husky448.jpg
# preprocessed: photos/husky///husky449.jpg
# preprocessed: photos/husky///husky45.jpg
# preprocessed: photos/husky///husky450.jpg
# preprocessed: photos/husky///husky451.jpg
# preprocessed: photos/husky///husky452.jpg
# preprocessed: photos/husky///husky453.jpg
# preprocessed: photos/husky///husky455.jpg
# preprocessed: photos/husky///husky456.jpg
# preprocessed: photos/husky///husky457.jpg
# preprocessed: photos/husky///husky458.jpg
# preprocessed: photos/husky///husky46.jpg
# preprocessed: photos/husky///husky460.jpg
# preprocessed: photos/husky///husky461.jpg
# preprocessed: photos/husky///husky462.jpg
# preprocessed: photos/husky///husky463.jpg
# preprocessed: photos/husky///husky466.jpg
# preprocessed: photos/husky///husky467.jpg
# preprocessed: photos/husky///husky468.jpg
# preprocessed: photos/husky///husky469.jpg
# preprocessed: photos/husky///husky47.jpg
# preprocessed: photos/husky///husky470.jpg
# preprocessed: photos/husky///husky471.jpg
# preprocessed: photos/husky///husky474.jpg
# preprocessed: photos/husky///husky475.jpg
# preprocessed: photos/husky///husky477.jpg
# preprocessed: photos/husky///husky478.jpg
# preprocessed: photos/husky///husky479.jpg
# preprocessed: photos/husky///husky48.jpg
# preprocessed: photos/husky///husky480.jpg
# preprocessed: photos/husky///husky481.jpg
# preprocessed: photos/husky///husky482.jpg
# preprocessed: photos/husky///husky483.jpg
# preprocessed: photos/husky///husky484.jpg
# preprocessed: photos/husky///husky485.jpg
# preprocessed: photos/husky///husky486.jpg
# preprocessed: photos/husky///husky487.jpg
# preprocessed: photos/husky///husky488.jpg
# preprocessed: photos/husky///husky489.jpg
# preprocessed: photos/husky///husky49.jpg
# preprocessed: photos/husky///husky490.jpg
# preprocessed: photos/husky///husky491.jpg
# preprocessed: photos/husky///husky492.jpg
# preprocessed: photos/husky///husky493.jpg
# preprocessed: photos/husky///husky494.jpg
# preprocessed: photos/husky///husky495.jpg
# preprocessed: photos/husky///husky496.jpg
# preprocessed: photos/husky///husky497.jpg
# preprocessed: photos/husky///husky498.jpg
# preprocessed: photos/husky///husky499.jpg
# preprocessed: photos/husky///husky5.jpg
# preprocessed: photos/husky///husky50.jpg
# preprocessed: photos/husky///husky500.jpg
# preprocessed: photos/husky///husky501.jpg
# preprocessed: photos/husky///husky502.jpg
# preprocessed: photos/husky///husky503.jpg
# preprocessed: photos/husky///husky504.jpg
# preprocessed: photos/husky///husky505.jpg
# preprocessed: photos/husky///husky506.jpg
# preprocessed: photos/husky///husky507.jpg
# preprocessed: photos/husky///husky508.jpg
# preprocessed: photos/husky///husky509.jpg
# preprocessed: photos/husky///husky51.jpg
# preprocessed: photos/husky///husky510.jpg
# preprocessed: photos/husky///husky511.jpg
# preprocessed: photos/husky///husky512.jpg
# preprocessed: photos/husky///husky513.jpg
# preprocessed: photos/husky///husky514.jpg
# preprocessed: photos/husky///husky515.jpg
# preprocessed: photos/husky///husky516.jpg
# preprocessed: photos/husky///husky517.jpg
# preprocessed: photos/husky///husky519.jpg
# preprocessed: photos/husky///husky52.jpg
# preprocessed: photos/husky///husky520.jpg
# preprocessed: photos/husky///husky521.jpg
# preprocessed: photos/husky///husky522.jpg
# preprocessed: photos/husky///husky53.jpg
# preprocessed: photos/husky///husky54.jpg
# preprocessed: photos/husky///husky55.jpg
# preprocessed: photos/husky///husky56.jpg
# preprocessed: photos/husky///husky57.jpg
# preprocessed: photos/husky///husky58.jpg
# preprocessed: photos/husky///husky59.jpg
# preprocessed: photos/husky///husky6.jpg
# preprocessed: photos/husky///husky60.jpg
# preprocessed: photos/husky///husky61.jpg
# preprocessed: photos/husky///husky62.jpg
# preprocessed: photos/husky///husky63.jpg
# preprocessed: photos/husky///husky64.jpg
# preprocessed: photos/husky///husky65.jpg
# preprocessed: photos/husky///husky66.jpg
# preprocessed: photos/husky///husky67.jpg
# preprocessed: photos/husky///husky68.jpg
# preprocessed: photos/husky///husky69.jpg
# preprocessed: photos/husky///husky7.jpg
# preprocessed: photos/husky///husky70.jpg
# preprocessed: photos/husky///husky71.jpg
# preprocessed: photos/husky///husky72.jpg
# preprocessed: photos/husky///husky73.jpg
# preprocessed: photos/husky///husky74.jpg
# preprocessed: photos/husky///husky75.jpg
# preprocessed: photos/husky///husky76.jpg
# preprocessed: photos/husky///husky77.jpg
# preprocessed: photos/husky///husky78.jpg
# preprocessed: photos/husky///husky79.jpg
# preprocessed: photos/husky///husky8.jpg
# preprocessed: photos/husky///husky80.jpg
# preprocessed: photos/husky///husky81.jpg
# preprocessed: photos/husky///husky82.jpg
# preprocessed: photos/husky///husky83.jpg
# preprocessed: photos/husky///husky84.jpg
# preprocessed: photos/husky///husky85.jpg
# preprocessed: photos/husky///husky86.jpg
# preprocessed: photos/husky///husky87.jpg
# preprocessed: photos/husky///husky88.jpg
# preprocessed: photos/husky///husky89.jpg
# preprocessed: photos/husky///husky9.jpg
# preprocessed: photos/husky///husky90.jpg
# preprocessed: photos/husky///husky91.jpg
# preprocessed: photos/husky///husky92.jpg
# preprocessed: photos/husky///husky93.jpg
# preprocessed: photos/husky///husky94.jpg
# preprocessed: photos/husky///husky95.jpg
# preprocessed: photos/husky///husky96.jpg
# preprocessed: photos/husky///husky97.jpg
# preprocessed: photos/husky///husky98.jpg
# preprocessed: photos/husky///husky99.jpg
# preprocessed: photos/wolf///wolf10.jpg
# preprocessed: photos/wolf///wolf100.jpg
# preprocessed: photos/wolf///wolf101.jpg
# preprocessed: photos/wolf///wolf102.jpg
# preprocessed: photos/wolf///wolf103.jpg
# preprocessed: photos/wolf///wolf104.jpg
# preprocessed: photos/wolf///wolf105.jpg
# preprocessed: photos/wolf///wolf106.jpg
# preprocessed: photos/wolf///wolf108.jpg
# preprocessed: photos/wolf///wolf109.jpg
# preprocessed: photos/wolf///wolf11.jpg
# preprocessed: photos/wolf///wolf110.jpg
# preprocessed: photos/wolf///wolf113.jpg
# preprocessed: photos/wolf///wolf115.jpg
# preprocessed: photos/wolf///wolf116.jpg
# preprocessed: photos/wolf///wolf117.jpg
# preprocessed: photos/wolf///wolf118.jpg
# preprocessed: photos/wolf///wolf119.jpg
# preprocessed: photos/wolf///wolf12.jpg
# preprocessed: photos/wolf///wolf120.jpg
# preprocessed: photos/wolf///wolf122.jpg
# preprocessed: photos/wolf///wolf124.jpg
# preprocessed: photos/wolf///wolf125.jpg
# preprocessed: photos/wolf///wolf126.jpg
# preprocessed: photos/wolf///wolf127.jpg
# preprocessed: photos/wolf///wolf128.jpg
# preprocessed: photos/wolf///wolf129.jpg
# preprocessed: photos/wolf///wolf13.jpg
# preprocessed: photos/wolf///wolf131.jpg
# preprocessed: photos/wolf///wolf133.jpg
# preprocessed: photos/wolf///wolf134.jpg
# preprocessed: photos/wolf///wolf138.jpg
# preprocessed: photos/wolf///wolf139.jpg
# preprocessed: photos/wolf///wolf14.jpg
# preprocessed: photos/wolf///wolf141.jpg
# preprocessed: photos/wolf///wolf142.jpg
# preprocessed: photos/wolf///wolf143.jpg
# preprocessed: photos/wolf///wolf144.jpg
# preprocessed: photos/wolf///wolf145.jpg
# preprocessed: photos/wolf///wolf146.jpg
# preprocessed: photos/wolf///wolf147.jpg
# preprocessed: photos/wolf///wolf148.jpg
# preprocessed: photos/wolf///wolf149.jpg
# preprocessed: photos/wolf///wolf15.jpg
# preprocessed: photos/wolf///wolf150.jpg
# preprocessed: photos/wolf///wolf151.jpg
# preprocessed: photos/wolf///wolf152.jpg
# preprocessed: photos/wolf///wolf153.jpg
# preprocessed: photos/wolf///wolf155.jpg
# preprocessed: photos/wolf///wolf156.jpg
# preprocessed: photos/wolf///wolf157.jpg
# preprocessed: photos/wolf///wolf158.jpg
# preprocessed: photos/wolf///wolf16.jpg
# preprocessed: photos/wolf///wolf160.jpg
# preprocessed: photos/wolf///wolf161.jpg
# preprocessed: photos/wolf///wolf162.jpg
# preprocessed: photos/wolf///wolf163.jpg
# preprocessed: photos/wolf///wolf165.jpg
# preprocessed: photos/wolf///wolf166.jpg
# preprocessed: photos/wolf///wolf167.jpg
# preprocessed: photos/wolf///wolf168.jpg
# preprocessed: photos/wolf///wolf169.jpg
# preprocessed: photos/wolf///wolf17.jpg
# preprocessed: photos/wolf///wolf170.jpg
# preprocessed: photos/wolf///wolf171.jpg
# preprocessed: photos/wolf///wolf172.jpg
# preprocessed: photos/wolf///wolf173.jpg
# preprocessed: photos/wolf///wolf174.jpg
# preprocessed: photos/wolf///wolf175.jpg
# preprocessed: photos/wolf///wolf176.jpg
# preprocessed: photos/wolf///wolf178.jpg
# preprocessed: photos/wolf///wolf179.jpg
# preprocessed: photos/wolf///wolf18.jpg
# preprocessed: photos/wolf///wolf180.jpg
# preprocessed: photos/wolf///wolf182.jpg
# preprocessed: photos/wolf///wolf183.jpg
# preprocessed: photos/wolf///wolf184.jpg
# preprocessed: photos/wolf///wolf185.jpg
# preprocessed: photos/wolf///wolf186.jpg
# preprocessed: photos/wolf///wolf187.jpg
# preprocessed: photos/wolf///wolf19.jpg
# preprocessed: photos/wolf///wolf190.jpg
# preprocessed: photos/wolf///wolf191.jpg
# preprocessed: photos/wolf///wolf192.jpg
# preprocessed: photos/wolf///wolf193.jpg
# preprocessed: photos/wolf///wolf194.jpg
# preprocessed: photos/wolf///wolf195.jpg
# preprocessed: photos/wolf///wolf196.jpg
# preprocessed: photos/wolf///wolf197.jpg
# preprocessed: photos/wolf///wolf199.jpg
# preprocessed: photos/wolf///wolf20.jpg
# preprocessed: photos/wolf///wolf200.jpg
# preprocessed: photos/wolf///wolf201.jpg
# preprocessed: photos/wolf///wolf202.jpg
# preprocessed: photos/wolf///wolf203.jpg
# preprocessed: photos/wolf///wolf204.jpg
# preprocessed: photos/wolf///wolf205.jpg
# preprocessed: photos/wolf///wolf206.jpg
# preprocessed: photos/wolf///wolf208.jpg
# preprocessed: photos/wolf///wolf210.jpg
# preprocessed: photos/wolf///wolf212.jpg
# preprocessed: photos/wolf///wolf213.jpg
# preprocessed: photos/wolf///wolf214.jpg
# preprocessed: photos/wolf///wolf216.jpg
# preprocessed: photos/wolf///wolf218.jpg
# preprocessed: photos/wolf///wolf219.jpg
# preprocessed: photos/wolf///wolf22.jpg
# preprocessed: photos/wolf///wolf221.jpg
# preprocessed: photos/wolf///wolf222.jpg
# preprocessed: photos/wolf///wolf225.jpg
# preprocessed: photos/wolf///wolf228.jpg
# preprocessed: photos/wolf///wolf229.jpg
# preprocessed: photos/wolf///wolf23.jpg
# preprocessed: photos/wolf///wolf232.jpg
# preprocessed: photos/wolf///wolf233.jpg
# preprocessed: photos/wolf///wolf234.jpg
# preprocessed: photos/wolf///wolf237.jpg
# preprocessed: photos/wolf///wolf24.jpg
# preprocessed: photos/wolf///wolf241.jpg
# preprocessed: photos/wolf///wolf242.jpg
# preprocessed: photos/wolf///wolf243.jpg
# preprocessed: photos/wolf///wolf244.jpg
# preprocessed: photos/wolf///wolf245.jpg
# preprocessed: photos/wolf///wolf246.jpg
# preprocessed: photos/wolf///wolf247.jpg
# preprocessed: photos/wolf///wolf249.jpg
# preprocessed: photos/wolf///wolf25.jpg
# preprocessed: photos/wolf///wolf250.jpg
# preprocessed: photos/wolf///wolf252.jpg
# preprocessed: photos/wolf///wolf253.jpg
# preprocessed: photos/wolf///wolf254.jpg
# preprocessed: photos/wolf///wolf259.jpg
# preprocessed: photos/wolf///wolf26.jpg
# preprocessed: photos/wolf///wolf260.jpg
# preprocessed: photos/wolf///wolf261.jpg
# preprocessed: photos/wolf///wolf262.jpg
# preprocessed: photos/wolf///wolf263.jpg
# preprocessed: photos/wolf///wolf264.jpg
# preprocessed: photos/wolf///wolf265.jpg
# preprocessed: photos/wolf///wolf27.jpg
# preprocessed: photos/wolf///wolf271.jpg
# preprocessed: photos/wolf///wolf272.jpg
# preprocessed: photos/wolf///wolf273.jpg
# preprocessed: photos/wolf///wolf276.jpg
# preprocessed: photos/wolf///wolf279.jpg
# preprocessed: photos/wolf///wolf281.jpg
# preprocessed: photos/wolf///wolf282.jpg
# preprocessed: photos/wolf///wolf283.jpg
# preprocessed: photos/wolf///wolf284.jpg
# preprocessed: photos/wolf///wolf285.jpg
# preprocessed: photos/wolf///wolf286.jpg
# preprocessed: photos/wolf///wolf289.jpg
# preprocessed: photos/wolf///wolf29.jpg
# preprocessed: photos/wolf///wolf291.jpg
# preprocessed: photos/wolf///wolf294.jpg
# preprocessed: photos/wolf///wolf295.jpg
# preprocessed: photos/wolf///wolf296.jpg
# preprocessed: photos/wolf///wolf297.jpg
# preprocessed: photos/wolf///wolf30.jpg
# preprocessed: photos/wolf///wolf303.jpg
# preprocessed: photos/wolf///wolf305.jpg
# preprocessed: photos/wolf///wolf308.jpg
# preprocessed: photos/wolf///wolf31.jpg
# preprocessed: photos/wolf///wolf310.jpg
# preprocessed: photos/wolf///wolf311.jpg
# preprocessed: photos/wolf///wolf312.jpg
# preprocessed: photos/wolf///wolf313.jpg
# preprocessed: photos/wolf///wolf317.jpg
# preprocessed: photos/wolf///wolf318.jpg
# preprocessed: photos/wolf///wolf32.jpg
# preprocessed: photos/wolf///wolf321.jpg
# preprocessed: photos/wolf///wolf322.jpg
# preprocessed: photos/wolf///wolf324.jpg
# preprocessed: photos/wolf///wolf327.jpg
# preprocessed: photos/wolf///wolf328.jpg
# preprocessed: photos/wolf///wolf33.jpg
# preprocessed: photos/wolf///wolf330.jpg
# preprocessed: photos/wolf///wolf331.jpg
# preprocessed: photos/wolf///wolf333.jpg
# preprocessed: photos/wolf///wolf336.jpg
# preprocessed: photos/wolf///wolf338.jpg
# preprocessed: photos/wolf///wolf339.jpg
# preprocessed: photos/wolf///wolf342.jpg
# preprocessed: photos/wolf///wolf343.jpg
# preprocessed: photos/wolf///wolf344.jpg
# preprocessed: photos/wolf///wolf345.jpg
# preprocessed: photos/wolf///wolf346.jpg
# preprocessed: photos/wolf///wolf349.jpg
# preprocessed: photos/wolf///wolf35.jpg
# preprocessed: photos/wolf///wolf350.jpg
# preprocessed: photos/wolf///wolf351.jpg
# preprocessed: photos/wolf///wolf352.jpg
# preprocessed: photos/wolf///wolf353.jpg
# preprocessed: photos/wolf///wolf354.jpg
# preprocessed: photos/wolf///wolf355.jpg
# preprocessed: photos/wolf///wolf356.jpg
# preprocessed: photos/wolf///wolf357.jpg
# preprocessed: photos/wolf///wolf358.jpg
# preprocessed: photos/wolf///wolf36.jpg
# preprocessed: photos/wolf///wolf362.jpg
# preprocessed: photos/wolf///wolf364.jpg
# preprocessed: photos/wolf///wolf366.jpg
# preprocessed: photos/wolf///wolf367.jpg
# preprocessed: photos/wolf///wolf369.jpg
# preprocessed: photos/wolf///wolf37.jpg
# preprocessed: photos/wolf///wolf373.jpg
# preprocessed: photos/wolf///wolf375.jpg
# preprocessed: photos/wolf///wolf376.jpg
# preprocessed: photos/wolf///wolf378.jpg
# preprocessed: photos/wolf///wolf379.jpg
# preprocessed: photos/wolf///wolf38.jpg
# preprocessed: photos/wolf///wolf380.jpg
# preprocessed: photos/wolf///wolf382.jpg
# preprocessed: photos/wolf///wolf383.jpg
# preprocessed: photos/wolf///wolf384.jpg
# preprocessed: photos/wolf///wolf385.jpg
# preprocessed: photos/wolf///wolf386.jpg
# preprocessed: photos/wolf///wolf387.jpg
# preprocessed: photos/wolf///wolf388.jpg
# preprocessed: photos/wolf///wolf389.jpg
# preprocessed: photos/wolf///wolf39.jpg
# preprocessed: photos/wolf///wolf390.jpg
# preprocessed: photos/wolf///wolf391.jpg
# preprocessed: photos/wolf///wolf393.jpg
# preprocessed: photos/wolf///wolf396.jpg
# preprocessed: photos/wolf///wolf398.jpg
# preprocessed: photos/wolf///wolf399.jpg
# preprocessed: photos/wolf///wolf40.jpg
# preprocessed: photos/wolf///wolf401.jpg
# preprocessed: photos/wolf///wolf402.jpg
# preprocessed: photos/wolf///wolf403.jpg
# preprocessed: photos/wolf///wolf408.jpg
# preprocessed: photos/wolf///wolf409.jpg
# preprocessed: photos/wolf///wolf41.jpg
# preprocessed: photos/wolf///wolf410.jpg
# preprocessed: photos/wolf///wolf411.jpg
# preprocessed: photos/wolf///wolf412.jpg
# preprocessed: photos/wolf///wolf413.jpg
# preprocessed: photos/wolf///wolf415.jpg
# preprocessed: photos/wolf///wolf416.jpg
# preprocessed: photos/wolf///wolf418.jpg
# preprocessed: photos/wolf///wolf419.jpg
# preprocessed: photos/wolf///wolf42.jpg
# preprocessed: photos/wolf///wolf420.jpg
# preprocessed: photos/wolf///wolf422.jpg
# preprocessed: photos/wolf///wolf424.jpg
# preprocessed: photos/wolf///wolf425.jpg
# preprocessed: photos/wolf///wolf426.jpg
# preprocessed: photos/wolf///wolf428.jpg
# preprocessed: photos/wolf///wolf429.jpg
# preprocessed: photos/wolf///wolf43.jpg
# preprocessed: photos/wolf///wolf431.jpg
# preprocessed: photos/wolf///wolf432.jpg
# preprocessed: photos/wolf///wolf433.jpg
# preprocessed: photos/wolf///wolf434.jpg
# preprocessed: photos/wolf///wolf435.jpg
# preprocessed: photos/wolf///wolf440.jpg
# preprocessed: photos/wolf///wolf442.jpg
# preprocessed: photos/wolf///wolf443.jpg
# preprocessed: photos/wolf///wolf444.jpg
# preprocessed: photos/wolf///wolf446.jpg
# preprocessed: photos/wolf///wolf447.jpg
# preprocessed: photos/wolf///wolf448.jpg
# preprocessed: photos/wolf///wolf449.jpg
# preprocessed: photos/wolf///wolf45.jpg
# preprocessed: photos/wolf///wolf450.jpg
# preprocessed: photos/wolf///wolf451.jpg
# preprocessed: photos/wolf///wolf454.jpg
# preprocessed: photos/wolf///wolf457.jpg
# preprocessed: photos/wolf///wolf458.jpg
# preprocessed: photos/wolf///wolf459.jpg
# preprocessed: photos/wolf///wolf46.jpg
# preprocessed: photos/wolf///wolf460.jpg
# preprocessed: photos/wolf///wolf461.jpg
# preprocessed: photos/wolf///wolf465.jpg
# preprocessed: photos/wolf///wolf466.jpg
# preprocessed: photos/wolf///wolf467.jpg
# preprocessed: photos/wolf///wolf468.jpg
# preprocessed: photos/wolf///wolf469.jpg
# preprocessed: photos/wolf///wolf47.jpg
# preprocessed: photos/wolf///wolf470.jpg
# preprocessed: photos/wolf///wolf471.jpg
# preprocessed: photos/wolf///wolf473.jpg
# preprocessed: photos/wolf///wolf474.jpg
# preprocessed: photos/wolf///wolf476.jpg
# preprocessed: photos/wolf///wolf477.jpg
# preprocessed: photos/wolf///wolf479.jpg
# preprocessed: photos/wolf///wolf48.jpg
# preprocessed: photos/wolf///wolf480.jpg
# preprocessed: photos/wolf///wolf481.jpg
# preprocessed: photos/wolf///wolf482.jpg
# preprocessed: photos/wolf///wolf483.jpg
# preprocessed: photos/wolf///wolf484.jpg
# preprocessed: photos/wolf///wolf487.jpg
# preprocessed: photos/wolf///wolf488.jpg
# preprocessed: photos/wolf///wolf489.jpg
# preprocessed: photos/wolf///wolf49.jpg
# preprocessed: photos/wolf///wolf490.jpg
# preprocessed: photos/wolf///wolf491.jpg
# preprocessed: photos/wolf///wolf493.jpg
# preprocessed: photos/wolf///wolf494.jpg
# preprocessed: photos/wolf///wolf495.jpg
# preprocessed: photos/wolf///wolf496.jpg
# preprocessed: photos/wolf///wolf499.jpg
# preprocessed: photos/wolf///wolf5.jpg
# preprocessed: photos/wolf///wolf50.jpg
# preprocessed: photos/wolf///wolf500.jpg
# preprocessed: photos/wolf///wolf501.jpg
# preprocessed: photos/wolf///wolf504.jpg
# preprocessed: photos/wolf///wolf505.jpg
# preprocessed: photos/wolf///wolf506.jpg
# preprocessed: photos/wolf///wolf508.jpg
# preprocessed: photos/wolf///wolf51.jpg
# preprocessed: photos/wolf///wolf511.jpg
# preprocessed: photos/wolf///wolf512.jpg
# preprocessed: photos/wolf///wolf513.jpg
# preprocessed: photos/wolf///wolf516.jpg
# preprocessed: photos/wolf///wolf52.jpg
# preprocessed: photos/wolf///wolf53.jpg
# preprocessed: photos/wolf///wolf54.jpg
# preprocessed: photos/wolf///wolf55.jpg
# preprocessed: photos/wolf///wolf56.jpg
# preprocessed: photos/wolf///wolf57.jpg
# preprocessed: photos/wolf///wolf59.jpg
# preprocessed: photos/wolf///wolf6.jpg
# preprocessed: photos/wolf///wolf60.jpg
# preprocessed: photos/wolf///wolf61.jpg
# preprocessed: photos/wolf///wolf62.jpg
# preprocessed: photos/wolf///wolf63.jpg
# preprocessed: photos/wolf///wolf64.jpg
# preprocessed: photos/wolf///wolf65.jpg
# preprocessed: photos/wolf///wolf66.jpg
# preprocessed: photos/wolf///wolf67.jpg
# preprocessed: photos/wolf///wolf68.jpg
# preprocessed: photos/wolf///wolf69.jpg
# preprocessed: photos/wolf///wolf7.jpg
# preprocessed: photos/wolf///wolf70.jpg
# preprocessed: photos/wolf///wolf72.jpg
# preprocessed: photos/wolf///wolf73.jpg
# preprocessed: photos/wolf///wolf75.jpg
# preprocessed: photos/wolf///wolf77.jpg
# preprocessed: photos/wolf///wolf78.jpg
# preprocessed: photos/wolf///wolf79.jpg
# preprocessed: photos/wolf///wolf8.jpg
# preprocessed: photos/wolf///wolf81.jpg
# preprocessed: photos/wolf///wolf83.jpg
# preprocessed: photos/wolf///wolf84.jpg
# preprocessed: photos/wolf///wolf86.jpg
# preprocessed: photos/wolf///wolf87.jpg
# preprocessed: photos/wolf///wolf88.jpg
# preprocessed: photos/wolf///wolf89.jpg
# preprocessed: photos/wolf///wolf9.jpg
# preprocessed: photos/wolf///wolf91.jpg
# preprocessed: photos/wolf///wolf92.jpg
# preprocessed: photos/wolf///wolf93.jpg
# preprocessed: photos/wolf///wolf94.jpg
# preprocessed: photos/wolf///wolf95.jpg
# preprocessed: photos/wolf///wolf98.jpg
# preprocessed: photos/wolf///wolf99.jpg
# (195, 25088) (359, 25088)
# (554, 25088) (554, 1)
# D:\Anaconda3\lib\site-packages\PIL\Image.py:952: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# D:\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:792: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))

# %%
#數據分離
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0)
print(X_train.shape,X_test.shape, X.shape)
# Out:
# (443, 25088) (111, 25088) (554, 25088)

# %%
#建立MLP模型
from keras.models import Sequential
from keras.layers import Dense
model = Sequential()
model.add(Dense(units=10, activation='relu', input_dim=25088))
model.add(Dense(units=1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 10)                250890
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 250,901
# Trainable params: 250,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
#模型求解參數配置
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
#模型訓練
model.fit(X_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 443/443 [==============================] - 0s 496us/step - loss: 2.8950 - accuracy: 0.6862
# Epoch 2/50
# 443/443 [==============================] - 0s 333us/step - loss: 0.6391 - accuracy: 0.6795
# Epoch 3/50
# 443/443 [==============================] - 0s 295us/step - loss: 0.5783 - accuracy: 0.6727
# Epoch 4/50
# 443/443 [==============================] - 0s 280us/step - loss: 0.3678 - accuracy: 0.6795
# Epoch 5/50
# 443/443 [==============================] - 0s 293us/step - loss: 0.3845 - accuracy: 0.6817
# Epoch 6/50
# 443/443 [==============================] - 0s 287us/step - loss: 0.2919 - accuracy: 0.6930
# Epoch 7/50
# 443/443 [==============================] - 0s 281us/step - loss: 0.2583 - accuracy: 0.7675
# Epoch 8/50
# 443/443 [==============================] - 0s 303us/step - loss: 0.1208 - accuracy: 0.9549
# Epoch 9/50
# 443/443 [==============================] - 0s 314us/step - loss: 0.0725 - accuracy: 0.9729
# Epoch 10/50
# 443/443 [==============================] - 0s 321us/step - loss: 0.0295 - accuracy: 0.9774
# Epoch 11/50
# 443/443 [==============================] - 0s 289us/step - loss: 0.0177 - accuracy: 0.9910
# Epoch 12/50
# 443/443 [==============================] - 0s 262us/step - loss: 0.0140 - accuracy: 0.9932
# Epoch 13/50
# 443/443 [==============================] - 0s 281us/step - loss: 0.0096 - accuracy: 0.9955
# Epoch 14/50
# 443/443 [==============================] - 0s 282us/step - loss: 0.0065 - accuracy: 0.9955
# Epoch 15/50
# 443/443 [==============================] - 0s 294us/step - loss: 0.0065 - accuracy: 0.9955
# Epoch 16/50
# 443/443 [==============================] - 0s 271us/step - loss: 0.0067 - accuracy: 0.9955
# Epoch 17/50
# 443/443 [==============================] - 0s 294us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 18/50
# 443/443 [==============================] - 0s 271us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 19/50
# 443/443 [==============================] - 0s 269us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 20/50
# 443/443 [==============================] - 0s 307us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 21/50
# 443/443 [==============================] - 0s 271us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 22/50
# 443/443 [==============================] - 0s 287us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 23/50
# 443/443 [==============================] - 0s 293us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 24/50
# 443/443 [==============================] - 0s 280us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 25/50
# 443/443 [==============================] - 0s 293us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 26/50
# 443/443 [==============================] - 0s 272us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 27/50
# 443/443 [==============================] - 0s 293us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 28/50
# 443/443 [==============================] - 0s 291us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 29/50
# 443/443 [==============================] - 0s 294us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 30/50
# 443/443 [==============================] - 0s 303us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 31/50
# 443/443 [==============================] - 0s 292us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 32/50
# 443/443 [==============================] - 0s 343us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 33/50
# 443/443 [==============================] - 0s 279us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 34/50
# 443/443 [==============================] - 0s 271us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 35/50
# 443/443 [==============================] - 0s 279us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 36/50
# 443/443 [==============================] - 0s 281us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 37/50
# 443/443 [==============================] - 0s 302us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 38/50
# 443/443 [==============================] - 0s 293us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 39/50
# 443/443 [==============================] - 0s 307us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 40/50
# 443/443 [==============================] - 0s 311us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 41/50
# 443/443 [==============================] - 0s 280us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 42/50
# 443/443 [==============================] - 0s 293us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 43/50
# 443/443 [==============================] - 0s 293us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 44/50
# 443/443 [==============================] - 0s 273us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 45/50
# 443/443 [==============================] - 0s 310us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 46/50
# 443/443 [==============================] - 0s 300us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 47/50
# 443/443 [==============================] - 0s 283us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 48/50
# 443/443 [==============================] - 0s 273us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 49/50
# 443/443 [==============================] - 0s 286us/step - loss: 0.0063 - accuracy: 0.9955
# Epoch 50/50
# 443/443 [==============================] - 0s 293us/step - loss: 0.0063 - accuracy: 0.9955

# %%
#模型表現評估
from sklearn.metrics import accuracy_score
y_train_predict = model.predict_classes(X_train)
accuracy_train = accuracy_score(y_train, y_train_predict)
print(accuracy_train)
# Out:
# 0.9954853273137697

# %%
#測試機預測準確率
y_test_predict = model.predict_classes(X_test)
accuracy_test = accuracy_score(y_test, y_test_predict)
print(accuracy_test)
# Out:
# 0.9369369369369369

# %%
# predict 1 pictures
pic1 = 'photos/husky_test/husky1.jpg'
pic1 = load_img(pic1,target_size=(224,224))
pic1_array = img_to_array(pic1)
pic1_array = np.expand_dims(pic1_array, axis=0)
pic1_features = model_vgg.predict(pic1_array)
pic1_features = pic1_features.reshape(1,7*7*512)
#mlp
result = model.predict_classes(pic1_features)
print('husky' if result==0 else 'wolf')
# Out:
# husky

# %%
fig3 = plt.figure()
plt.imshow(pic1)

# %%
# test the 8 pictures
pics = [p for p in range(1,5)]
fig3 = plt.figure(figsize=(10,10))
img_names=[]
for j in pics:
    img_name = 'photos/test8/husky'+str(j)+'.jpg'
    img_names.append(img_name)
for k in pics:
    img_name = 'photos/test8/wolf'+str(k)+'.jpg'
    img_names.append(img_name)

index = 1

for name in img_names:
    pic = load_img(name,target_size=(224,224))
    pic_array = img_to_array(pic)
    pic_array = np.expand_dims(pic_array, axis=0)
    pic_features = model_vgg.predict(pic_array)
    pic_features = pic_features.reshape(1,7*7*512)
    #mlp
    result = model.predict_classes(pic_features)
    print('husky' if result==0 else 'wolf')

    plt.subplot(2,4,index)
    plt.imshow(pic)
    plt.title("predicted: Husky" if result ==0 else "predicted: Wolf")
    index += 1
# Out:
# husky
# husky
# husky
# husky
# wolf
# wolf
# wolf
# wolf

# %%
# save model
model.save('arwen.h5')
